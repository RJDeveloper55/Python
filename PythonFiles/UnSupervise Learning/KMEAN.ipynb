# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
#from sklearn.cluster import KMeans

# %matplotlib inline
X= -2 * np.random.rand(100,2)
X1 = 1 + 2 * np.random.rand(50,2)
X[50:100, :] = X1
plt.scatter(X[ : , 0], X[ :, 1], s = 50, c = 'g')
plt.show()

# %%
Kmean = KMeans(n_clusters=4)
Kmean.fit(X)
Kmean.labels_
Kmean.cluster_centers_
plt.scatter(X[ : , 0], X[ : , 1], s =50, c='b')
plt.scatter(-0.94665068, -0.97138368, s=200, c='g', marker='s')
plt.scatter(2.01559419, 2.02597093, s=200, c='r', marker='s')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline
X= -2 * np.random.rand(100,2)
X1 = 1 + 2 * np.random.rand(50,2)
X[50:100, :] = X1
plt.scatter(X[ : , 0], X[ :, 1], s = 50, c = 'g')
plt.show()
from sklearn.cluster import KMeans
Kmean = KMeans(n_clusters=4)
Kmean.fit(X)
Kmean.cluster_centers_
plt.scatter(X[ : , 0], X[ : , 1], s =50, c='b')
plt.scatter(-0.94665068, -0.97138368, s=200, c='g', marker='s')
plt.scatter(2.01559419, 2.02597093, s=200, c='r', marker='s')
plt.show()
Kmean.labels_
sample_test=np.array([-3.0,-3.0])
second_test=sample_test.reshape(1, -1)
Kmean.predict(second_test)
# Out:
# array([0])

# %%
import pandas as pd

# %%
df = pd.read_csv("opsd_germany_daily.csv")

# %%
df
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
pd.to_datetime(['2018-01-05', '7/8/1952', 'Oct 10, 1995'])
# Out:
# DatetimeIndex(['2018-01-05', '1952-07-08', '1995-10-10'], dtype='datetime64[ns]', freq=None)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date',inplace=True)

# %%
df.tail(5)
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156

# %%
df.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
df['Year'] = df.index.year

# %%
df['Month'] = df.index.month

# %%
df['Day'] = df.index.day

# %%
#df['Weekday_Name'] = df.index.weekday_name

# %%
df['Consumption'].plot()

# %%
cols_plot = ['Consumption','Solar','Wind']

# %%
axes  = df[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel("Daily Total (GWh)")

# %%
ax = df.loc['2017', 'Consumption'].plot()
ax.set_ylabel('Daily Consumption (GWh)');

# %%
ax = df.loc['2017', 'Wind'].plot()

# %%
ax = df.loc['2017-jan', 'Solar'].plot()

# %%
df2 = pd.DataFrame()

# %%
df2["Testing"] = df.Consumption.resample('W').mean()

# %%
df2.head(3)
df2.plot()

# %%
# Out:
#                       Consumption  Wind  Solar  Wind+Solar  Year  Month  Day
# 2017-01-01 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-02 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-03 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-04 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-05 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-06 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-07 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-08 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-09 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN
# 2017-01-10 morning            NaN   NaN    NaN         NaN   NaN    NaN  NaN
#            afternoon          NaN   NaN    NaN         NaN   NaN    NaN  NaN

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.index, df.Consumption)

# %%
plt.show()

# %%
df.plot()
df['Year'] = df['Date'].index.Year
df['Month'] = df['Date'].index.Month
df['Day'] = df['Date'].index.Day
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-30a9ed23b30b> in <module>
#       1 df.plot()
# ----> 2 df['Year'] = df['Date'].index.Year
#       3 df['Month'] = df['Date'].index.Month
#       4 df['Day'] = df['Date'].index.Day
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
